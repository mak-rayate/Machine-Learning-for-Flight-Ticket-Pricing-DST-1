# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import time
df=pd.read_csv("DDD.csv")

# %%
df
# Out:
#    Code IMP_codes
# 0   AGR       DEL
# 1   DIB       BOM
# 2   HYD       BLR
# 3   BHJ       HYD
# 4   HBX       MAA
# ..  ...       ...
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
#
# [84 rows x 2 columns]

# %%
df["IMP_codes"].iloc[29]
# Out:
# 'TRZ'

# %%
from tqdm import tqdm
price=[]
cities=[]
departure_time=[]
arrival_time=[]
via=[]
airline=[]
cabin=[]
driver = webdriver.Chrome()
for q in ['E','PE','B']:
    for z in range(26,31):
        for m in range(5):
            for n in range(30):
                if df["IMP_codes"].iloc[m]!=df["IMP_codes"].iloc[n]:
                    print("source=",m, "destination=",n, "Dates=",z)
                    print(df["IMP_codes"].iloc[m],df["IMP_codes"].iloc[n])
                    url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass="+q+"&ccde=IN&lang=eng"
                #driver = webdriver.Chrome("C:/chromedriver.exe")
                    driver.get(url)
                    soup=BeautifulSoup(driver.page_source, 'lxml')

                    price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
                    flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
                    time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
                    layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})
                    airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})

#price_info
                    for i,j in enumerate(price_info):
                        if i<10:
                           a=str(j)
                           price.append(a[43:len(a)-4])
                           cabin.append(q)
    #flights_info
                    for i,j in enumerate(flights_info):
                        if i<20:
                            k=str(j)
                            if len(k)>45:
                                cities.append(k[29:(len(k)-4)])

    #time_info
                    for i,j in enumerate(time_info):
                        if i<20:
                            k=str(j)
                            if (i%2==0):
                                departure_time.append(k[82:87])
                            if (i%2!=0):
                                arrival_time.append(k[82:87])

    #layover_info
                    for i,j in enumerate(layover_info):
                        if i<10:
                            k=str(j)
                            via.append(k[30:len(k)-4])

    #airline_info
                    for i,j in enumerate(airline_info):
                        if i<10:            
                            k=str(j)
                            airline.append(k[45:len(k)-7])
                    print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))
                    print("**"*50)
# Out:
# source= 0 destination= 1 Dates= 26
# DEL BOM
# 10 10 10 10 10 10
# ****************************************************************************************************
# source= 0 destination= 2 Dates= 26
# DEL BLR
# 20 20 20 20 20 20
# ****************************************************************************************************
# source= 0 destination= 3 Dates= 26
# DEL HYD
# 30 30 30 30 30 30
# ****************************************************************************************************
# source= 0 destination= 4 Dates= 26
# DEL MAA
# 40 40 40 40 40 40
# ****************************************************************************************************
# source= 0 destination= 5 Dates= 26
# DEL CCU
# 50 50 50 50 50 50
# ****************************************************************************************************
# source= 0 destination= 6 Dates= 26
# DEL COK
# 60 60 60 60 60 60
# ****************************************************************************************************
# source= 0 destination= 7 Dates= 26
# DEL GOI
# 70 70 70 70 70 70
# ****************************************************************************************************
# source= 0 destination= 8 Dates= 26
# DEL PNQ
# 80 80 80 80 80 80
# ****************************************************************************************************
# source= 0 destination= 9 Dates= 26
# DEL GAU
# 90 90 90 90 90 90
# ****************************************************************************************************
# source= 0 destination= 10 Dates= 26
# DEL LKO
# 100 100 100 100 100 100
# ****************************************************************************************************
# source= 0 destination= 11 Dates= 26
# DEL JAI
# 110 110 110 110 110 110
# ****************************************************************************************************
# source= 0 destination= 12 Dates= 26
# DEL PAT
# 120 120 120 120 120 120
# ****************************************************************************************************
# source= 0 destination= 13 Dates= 26
# DEL TRV
# 130 130 130 130 130 130
# ****************************************************************************************************
# source= 0 destination= 14 Dates= 26
# DEL BBI
# 140 140 140 140 140 140
# ****************************************************************************************************
# source= 0 destination= 15 Dates= 26
# DEL CCJ
# 150 150 150 150 150 150
# ****************************************************************************************************
# source= 0 destination= 16 Dates= 26
# DEL IXB
# 160 160 160 160 160 160
# ****************************************************************************************************
# source= 0 destination= 17 Dates= 26
# DEL NAG
# 170 170 170 170 170 170
# ****************************************************************************************************
# source= 0 destination= 18 Dates= 26
# DEL VNS
# 180 180 180 180 180 180
# ****************************************************************************************************
# source= 0 destination= 19 Dates= 26
# DEL IDR
# 190 190 190 190 190 190
# ****************************************************************************************************
# source= 0 destination= 20 Dates= 26
# DEL CJB
# 200 200 200 200 200 200
# ****************************************************************************************************
# source= 0 destination= 21 Dates= 26
# DEL SXR
# 210 210 210 210 210 210
# ****************************************************************************************************
# source= 0 destination= 22 Dates= 26
# DEL VTZ
# 220 220 220 220 220 220
# ****************************************************************************************************
# source= 0 destination= 23 Dates= 26
# DEL IXR
# 230 230 230 230 230 230
# ****************************************************************************************************
# source= 0 destination= 24 Dates= 26
# DEL ATQ
# 240 240 240 240 240 240
# ****************************************************************************************************
# source= 0 destination= 25 Dates= 26
# DEL IXC
# 250 250 250 250 250 250
# ****************************************************************************************************
# source= 0 destination= 26 Dates= 26
# DEL RPR
# 260 260 260 260 260 260
# ****************************************************************************************************
# source= 0 destination= 27 Dates= 26
# DEL IXE
# 270 270 270 270 270 270
# ****************************************************************************************************
# source= 0 destination= 28 Dates= 26
# DEL IXZ
# 280 280 280 280 280 280
# ****************************************************************************************************
# source= 0 destination= 29 Dates= 26
# DEL TRZ
# 290 290 290 290 290 290
# ****************************************************************************************************
# source= 1 destination= 0 Dates= 26
# BOM DEL
# 300 300 300 300 300 300
# ****************************************************************************************************
# source= 1 destination= 2 Dates= 26
# BOM BLR
# 310 310 310 310 310 310
# ****************************************************************************************************
# source= 1 destination= 3 Dates= 26
# BOM HYD
# 320 320 320 320 320 320
# ****************************************************************************************************
# source= 1 destination= 4 Dates= 26
# BOM MAA
# 330 330 330 330 330 330
# ****************************************************************************************************
# source= 1 destination= 5 Dates= 26
# BOM CCU
# 330 330 330 330 330 330
# ****************************************************************************************************
# source= 1 destination= 6 Dates= 26
# BOM COK
# 340 340 340 340 340 340
# ****************************************************************************************************
# source= 1 destination= 7 Dates= 26
# BOM GOI
# 350 350 350 350 350 350
# ****************************************************************************************************
# source= 1 destination= 8 Dates= 26
# BOM PNQ
# 360 360 360 360 360 360
# ****************************************************************************************************
# source= 1 destination= 9 Dates= 26
# BOM GAU
# 360 360 360 360 360 360
# ****************************************************************************************************
# source= 1 destination= 10 Dates= 26
# BOM LKO
# 370 370 370 370 370 370
# ****************************************************************************************************
# source= 1 destination= 11 Dates= 26
# BOM JAI
# 380 380 380 380 380 380
# ****************************************************************************************************
# source= 1 destination= 12 Dates= 26
# BOM PAT
# 390 390 390 390 390 390
# ****************************************************************************************************
# source= 1 destination= 13 Dates= 26
# BOM TRV
# 400 400 400 400 400 400
# ****************************************************************************************************
# source= 1 destination= 14 Dates= 26
# BOM BBI
# 410 410 410 410 410 410
# ****************************************************************************************************
# source= 1 destination= 15 Dates= 26
# BOM CCJ
# 420 420 420 420 420 420
# ****************************************************************************************************
# source= 1 destination= 16 Dates= 26
# BOM IXB
# 430 430 430 430 430 430
# ****************************************************************************************************
# source= 1 destination= 17 Dates= 26
# BOM NAG
# 440 440 440 440 440 440
# ****************************************************************************************************
# source= 1 destination= 18 Dates= 26
# BOM VNS
# 450 450 450 450 450 450
# ****************************************************************************************************
# source= 1 destination= 19 Dates= 26
# BOM IDR
# 460 460 460 460 460 460
# ****************************************************************************************************
# source= 1 destination= 20 Dates= 26
# BOM CJB
# 470 470 470 470 470 470
# ****************************************************************************************************
# source= 1 destination= 21 Dates= 26
# BOM SXR
# 480 480 480 480 480 480
# ****************************************************************************************************
# source= 1 destination= 22 Dates= 26
# BOM VTZ
# 490 490 490 490 490 490
# ****************************************************************************************************
# source= 1 destination= 23 Dates= 26
# BOM IXR
# 500 500 500 500 500 500
# ****************************************************************************************************
# source= 1 destination= 24 Dates= 26
# BOM ATQ
# 510 510 510 510 510 510
# ****************************************************************************************************
# source= 1 destination= 25 Dates= 26
# BOM IXC
# 520 520 520 520 520 520
# ****************************************************************************************************
# source= 1 destination= 26 Dates= 26
# BOM RPR
# 530 530 530 530 530 530
# ****************************************************************************************************
# source= 1 destination= 27 Dates= 26
# BOM IXE
# 540 540 540 540 540 540
# ****************************************************************************************************
# source= 1 destination= 28 Dates= 26
# BOM IXZ
# 550 550 550 550 550 550
# ****************************************************************************************************
# source= 1 destination= 29 Dates= 26
# BOM TRZ
# 560 560 560 560 560 560
# ****************************************************************************************************
# source= 2 destination= 0 Dates= 26
# BLR DEL
# 570 570 570 570 570 570
# ****************************************************************************************************
# source= 2 destination= 1 Dates= 26
# BLR BOM
# 580 580 580 580 580 580
# ****************************************************************************************************
# source= 2 destination= 3 Dates= 26
# BLR HYD
# 590 590 590 590 590 590
# ****************************************************************************************************
# source= 2 destination= 4 Dates= 26
# BLR MAA
# 600 600 600 600 600 600
# ****************************************************************************************************
# source= 2 destination= 5 Dates= 26
# BLR CCU
# 610 610 610 610 610 610
# ****************************************************************************************************
# source= 2 destination= 6 Dates= 26
# BLR COK
# 620 620 620 620 620 620
# ****************************************************************************************************
# source= 2 destination= 7 Dates= 26
# BLR GOI
# 630 630 630 630 630 630
# ****************************************************************************************************
# source= 2 destination= 8 Dates= 26
# BLR PNQ
# 640 640 640 640 640 640
# ****************************************************************************************************
# source= 2 destination= 9 Dates= 26
# BLR GAU
# 650 650 650 650 650 650
# ****************************************************************************************************
# source= 2 destination= 10 Dates= 26
# BLR LKO
# 660 660 660 660 660 660
# ****************************************************************************************************
# source= 2 destination= 11 Dates= 26
# BLR JAI
# 670 670 670 670 670 670
# ****************************************************************************************************
# source= 2 destination= 12 Dates= 26
# BLR PAT
# 680 680 680 680 680 680
# ****************************************************************************************************
# source= 2 destination= 13 Dates= 26
# BLR TRV
# 690 690 690 690 690 690
# ****************************************************************************************************
# source= 2 destination= 14 Dates= 26
# BLR BBI
# 690 690 690 690 690 690
# ****************************************************************************************************
# source= 2 destination= 15 Dates= 26
# BLR CCJ
# 692 692 692 692 692 692
# ****************************************************************************************************
# source= 2 destination= 16 Dates= 26
# BLR IXB
# 702 702 702 702 702 702
# ****************************************************************************************************
# source= 2 destination= 17 Dates= 26
# BLR NAG
# 712 712 712 712 712 712
# ****************************************************************************************************
# source= 2 destination= 18 Dates= 26
# BLR VNS
# 722 722 722 722 722 722
# ****************************************************************************************************
# source= 2 destination= 19 Dates= 26
# BLR IDR
# 732 732 732 732 732 732
# ****************************************************************************************************
# source= 2 destination= 20 Dates= 26
# BLR CJB
# 742 742 742 742 742 742
# ****************************************************************************************************
# source= 2 destination= 21 Dates= 26
# BLR SXR
# 752 752 752 752 752 752
# ****************************************************************************************************
# source= 2 destination= 22 Dates= 26
# BLR VTZ
# 762 762 762 762 762 762
# ****************************************************************************************************
# source= 2 destination= 23 Dates= 26
# BLR IXR
# 772 772 772 772 772 772
# ****************************************************************************************************
# source= 2 destination= 24 Dates= 26
# BLR ATQ
# 782 782 782 782 782 782
# ****************************************************************************************************
# source= 2 destination= 25 Dates= 26
# BLR IXC
# 792 792 792 792 792 792
# ****************************************************************************************************
# source= 2 destination= 26 Dates= 26
# BLR RPR
# 802 802 802 802 802 802
# ****************************************************************************************************
# source= 2 destination= 27 Dates= 26
# BLR IXE
# 812 812 812 812 812 812
# ****************************************************************************************************
# source= 2 destination= 28 Dates= 26
# BLR IXZ
# 822 822 822 822 822 822
# ****************************************************************************************************
# source= 2 destination= 29 Dates= 26
# BLR TRZ
# 831 831 831 831 831 831
# ****************************************************************************************************
# source= 3 destination= 0 Dates= 26
# HYD DEL
# 841 841 841 841 841 841
# ****************************************************************************************************
# source= 3 destination= 1 Dates= 26
# HYD BOM
# 851 851 851 851 851 851
# ****************************************************************************************************
# source= 3 destination= 2 Dates= 26
# HYD BLR
# 861 861 861 861 861 861
# ****************************************************************************************************
# source= 3 destination= 4 Dates= 26
# HYD MAA
# 871 871 871 871 871 871
# ****************************************************************************************************
# source= 3 destination= 5 Dates= 26
# HYD CCU
# 881 881 881 881 881 881
# ****************************************************************************************************
# source= 3 destination= 6 Dates= 26
# HYD COK
# 891 891 891 891 891 891
# ****************************************************************************************************
# source= 3 destination= 7 Dates= 26
# HYD GOI
# 901 901 901 901 901 901
# ****************************************************************************************************
# source= 3 destination= 8 Dates= 26
# HYD PNQ
# 911 911 911 911 911 911
# ****************************************************************************************************
# source= 3 destination= 9 Dates= 26
# HYD GAU
# 921 921 921 921 921 921
# ****************************************************************************************************
# source= 3 destination= 10 Dates= 26
# HYD LKO
# 931 931 931 931 931 931
# ****************************************************************************************************
# source= 3 destination= 11 Dates= 26
# HYD JAI
# 941 941 941 941 941 941
# ****************************************************************************************************
# source= 3 destination= 12 Dates= 26
# HYD PAT
# 951 951 951 951 951 951
# ****************************************************************************************************
# source= 3 destination= 13 Dates= 26
# HYD TRV
# 961 961 961 961 961 961
# ****************************************************************************************************
# source= 3 destination= 14 Dates= 26
# HYD BBI
# 971 971 971 971 971 971
# ****************************************************************************************************
# source= 3 destination= 15 Dates= 26
# HYD CCJ
# 981 981 981 981 981 981
# ****************************************************************************************************
# source= 3 destination= 16 Dates= 26
# HYD IXB
# 991 991 991 991 991 991
# ****************************************************************************************************
# source= 3 destination= 17 Dates= 26
# HYD NAG
# 1001 1001 1001 1001 1001 1001
# ****************************************************************************************************
# source= 3 destination= 18 Dates= 26
# HYD VNS
# 1011 1011 1011 1011 1011 1011
# ****************************************************************************************************
# source= 3 destination= 19 Dates= 26
# HYD IDR
# 1021 1021 1021 1021 1021 1021
# ****************************************************************************************************
# source= 3 destination= 20 Dates= 26
# HYD CJB
# 1031 1031 1031 1031 1031 1031
# ****************************************************************************************************
# source= 3 destination= 21 Dates= 26
# HYD SXR
# 1041 1041 1041 1041 1041 1041
# ****************************************************************************************************
# source= 3 destination= 22 Dates= 26
# HYD VTZ
# 1051 1051 1051 1051 1051 1051
# ****************************************************************************************************
# source= 3 destination= 23 Dates= 26
# HYD IXR
# 1061 1061 1061 1061 1061 1061
# ****************************************************************************************************
# source= 3 destination= 24 Dates= 26
# HYD ATQ
# 1071 1071 1071 1071 1071 1071
# ****************************************************************************************************
# source= 3 destination= 25 Dates= 26
# HYD IXC
# 1081 1081 1081 1081 1081 1081
# ****************************************************************************************************
# source= 3 destination= 26 Dates= 26
# HYD RPR
# 1091 1091 1091 1091 1091 1091
# ****************************************************************************************************
# source= 3 destination= 27 Dates= 26
# HYD IXE
# 1101 1101 1101 1101 1101 1101
# ****************************************************************************************************
# source= 3 destination= 28 Dates= 26
# HYD IXZ
# 1111 1111 1111 1111 1111 1111
# ****************************************************************************************************
# source= 3 destination= 29 Dates= 26
# HYD TRZ
# 1121 1121 1121 1121 1121 1121
# ****************************************************************************************************
# source= 4 destination= 0 Dates= 26
# MAA DEL
# 1131 1131 1131 1131 1131 1131
# ****************************************************************************************************
# source= 4 destination= 1 Dates= 26
# MAA BOM
# 1141 1141 1141 1141 1141 1141
# ****************************************************************************************************
# source= 4 destination= 2 Dates= 26
# MAA BLR
# 1151 1151 1151 1151 1151 1151
# ****************************************************************************************************
# source= 4 destination= 3 Dates= 26
# MAA HYD
# 1161 1161 1161 1161 1161 1161
# ****************************************************************************************************
# source= 4 destination= 5 Dates= 26
# MAA CCU
# 1171 1171 1171 1171 1171 1171
# ****************************************************************************************************
# source= 4 destination= 6 Dates= 26
# MAA COK
# 1181 1181 1181 1181 1181 1181
# ****************************************************************************************************
# source= 4 destination= 7 Dates= 26
# MAA GOI
# 1191 1191 1191 1191 1191 1191
# ****************************************************************************************************
# source= 4 destination= 8 Dates= 26
# MAA PNQ
# 1201 1201 1201 1201 1201 1201
# ****************************************************************************************************
# source= 4 destination= 9 Dates= 26
# MAA GAU
# 1211 1211 1211 1211 1211 1211
# ****************************************************************************************************
# source= 4 destination= 10 Dates= 26
# MAA LKO
# 1221 1221 1221 1221 1221 1221
# ****************************************************************************************************
# source= 4 destination= 11 Dates= 26
# MAA JAI
# 1231 1231 1231 1231 1231 1231
# ****************************************************************************************************
# source= 4 destination= 12 Dates= 26
# MAA PAT
# 1241 1241 1241 1241 1241 1241
# ****************************************************************************************************
# source= 4 destination= 13 Dates= 26
# MAA TRV
# 1251 1251 1251 1251 1251 1251
# ****************************************************************************************************
# source= 4 destination= 14 Dates= 26
# MAA BBI
# 1261 1261 1261 1261 1261 1261
# ****************************************************************************************************
# source= 4 destination= 15 Dates= 26
# MAA CCJ
# 1265 1265 1265 1265 1265 1265
# ****************************************************************************************************
# source= 4 destination= 16 Dates= 26
# MAA IXB
# 1275 1275 1275 1275 1275 1275
# ****************************************************************************************************
# source= 4 destination= 17 Dates= 26
# MAA NAG
# 1285 1285 1285 1285 1285 1285
# ****************************************************************************************************
# source= 4 destination= 18 Dates= 26
# MAA VNS
# 1295 1295 1295 1295 1295 1295
# ****************************************************************************************************
# source= 4 destination= 19 Dates= 26
# MAA IDR
# 1305 1305 1305 1305 1305 1305
# ****************************************************************************************************
# source= 4 destination= 20 Dates= 26
# MAA CJB
# 1315 1315 1315 1315 1315 1315
# ****************************************************************************************************
# source= 4 destination= 21 Dates= 26
# MAA SXR
# 1325 1325 1325 1325 1325 1325
# ****************************************************************************************************
# source= 4 destination= 22 Dates= 26
# MAA VTZ
# 1335 1335 1335 1335 1335 1335
# ****************************************************************************************************
# source= 4 destination= 23 Dates= 26
# MAA IXR
# 1345 1345 1345 1345 1345 1345
# ****************************************************************************************************
# source= 4 destination= 24 Dates= 26
# MAA ATQ
# 1355 1355 1355 1355 1355 1355
# ****************************************************************************************************
# source= 4 destination= 25 Dates= 26
# MAA IXC
# 1365 1365 1365 1365 1365 1365
# ****************************************************************************************************
# source= 4 destination= 26 Dates= 26
# MAA RPR
# 1375 1375 1375 1375 1375 1375
# ****************************************************************************************************
# source= 4 destination= 27 Dates= 26
# MAA IXE
# 1385 1385 1385 1385 1385 1385
# ****************************************************************************************************
# source= 4 destination= 28 Dates= 26
# MAA IXZ
# 1395 1395 1395 1395 1395 1395
# ****************************************************************************************************
# source= 4 destination= 29 Dates= 26
# MAA TRZ
# 1398 1398 1398 1398 1398 1398
# ****************************************************************************************************
# source= 0 destination= 1 Dates= 27
# DEL BOM
# 1408 1408 1408 1408 1408 1408
# ****************************************************************************************************
# source= 0 destination= 2 Dates= 27
# DEL BLR
# 1418 1418 1418 1418 1418 1418
# ****************************************************************************************************
# source= 0 destination= 3 Dates= 27
# DEL HYD
# 1428 1428 1428 1428 1428 1428
# ****************************************************************************************************
# source= 0 destination= 4 Dates= 27
# DEL MAA
# 1438 1438 1438 1438 1438 1438
# ****************************************************************************************************
# source= 0 destination= 5 Dates= 27
# DEL CCU
# 1448 1448 1448 1448 1448 1448
# ****************************************************************************************************
# source= 0 destination= 6 Dates= 27
# DEL COK
# 1458 1458 1458 1458 1458 1458
# ****************************************************************************************************
# source= 0 destination= 7 Dates= 27
# DEL GOI
# 1468 1468 1468 1468 1468 1468
# ****************************************************************************************************
# source= 0 destination= 8 Dates= 27
# DEL PNQ
# 1478 1478 1478 1478 1478 1478
# ****************************************************************************************************
# source= 0 destination= 9 Dates= 27
# DEL GAU
# 1488 1488 1488 1488 1488 1488
# ****************************************************************************************************
# source= 0 destination= 10 Dates= 27
# DEL LKO
# 1498 1498 1498 1498 1498 1498
# ****************************************************************************************************
# source= 0 destination= 11 Dates= 27
# DEL JAI
# 1508 1508 1508 1508 1508 1508
# ****************************************************************************************************
# source= 0 destination= 12 Dates= 27
# DEL PAT
# 1518 1518 1518 1518 1518 1518
# ****************************************************************************************************
# source= 0 destination= 13 Dates= 27
# DEL TRV
# 1528 1528 1528 1528 1528 1528
# ****************************************************************************************************
# source= 0 destination= 14 Dates= 27
# DEL BBI
# 1538 1538 1538 1538 1538 1538
# ****************************************************************************************************
# source= 0 destination= 15 Dates= 27
# DEL CCJ
# 1539 1539 1539 1539 1539 1539
# ****************************************************************************************************
# source= 0 destination= 16 Dates= 27
# DEL IXB
# 1549 1549 1549 1549 1549 1549
# ****************************************************************************************************
# source= 0 destination= 17 Dates= 27
# DEL NAG
# 1559 1559 1559 1559 1559 1559
# ****************************************************************************************************
# source= 0 destination= 18 Dates= 27
# DEL VNS
# 1569 1569 1569 1569 1569 1569
# ****************************************************************************************************
# source= 0 destination= 19 Dates= 27
# DEL IDR
# 1579 1579 1579 1579 1579 1579
# ****************************************************************************************************
# source= 0 destination= 20 Dates= 27
# DEL CJB
# 1589 1589 1589 1589 1589 1589
# ****************************************************************************************************
# source= 0 destination= 21 Dates= 27
# DEL SXR
# 1599 1599 1599 1599 1599 1599
# ****************************************************************************************************
# source= 0 destination= 22 Dates= 27
# DEL VTZ
# 1599 1599 1599 1599 1599 1599
# ****************************************************************************************************
# source= 0 destination= 23 Dates= 27
# DEL IXR
# 1609 1609 1609 1609 1609 1609
# ****************************************************************************************************
# source= 0 destination= 24 Dates= 27
# DEL ATQ
# 1609 1609 1609 1609 1609 1609
# ****************************************************************************************************
# source= 0 destination= 25 Dates= 27
# DEL IXC
# 1619 1619 1619 1619 1619 1619
# ****************************************************************************************************
# source= 0 destination= 26 Dates= 27
# DEL RPR
# 1629 1629 1629 1629 1629 1629
# ****************************************************************************************************
# source= 0 destination= 27 Dates= 27
# DEL IXE
# 1639 1639 1639 1639 1639 1639
# ****************************************************************************************************
# source= 0 destination= 28 Dates= 27
# DEL IXZ
# 1649 1649 1649 1649 1649 1649
# ****************************************************************************************************
# source= 0 destination= 29 Dates= 27
# DEL TRZ
# 1659 1659 1659 1659 1659 1659
# ****************************************************************************************************
# source= 1 destination= 0 Dates= 27
# BOM DEL
# 1669 1669 1669 1669 1669 1669
# ****************************************************************************************************
# source= 1 destination= 2 Dates= 27
# BOM BLR
# 1679 1679 1679 1679 1679 1679
# ****************************************************************************************************
# source= 1 destination= 3 Dates= 27
# BOM HYD
# 1689 1689 1689 1689 1689 1689
# ****************************************************************************************************
# source= 1 destination= 4 Dates= 27
# BOM MAA
# 1699 1699 1699 1699 1699 1699
# ****************************************************************************************************
# source= 1 destination= 5 Dates= 27
# BOM CCU
# 1709 1709 1709 1709 1709 1709
# ****************************************************************************************************
# source= 1 destination= 6 Dates= 27
# BOM COK
# 1719 1719 1719 1719 1719 1719
# ****************************************************************************************************
# source= 1 destination= 7 Dates= 27
# BOM GOI
# 1729 1729 1729 1729 1729 1729
# ****************************************************************************************************
# source= 1 destination= 8 Dates= 27
# BOM PNQ
# 1739 1739 1739 1739 1739 1739
# ****************************************************************************************************
# source= 1 destination= 9 Dates= 27
# BOM GAU
# 1749 1749 1749 1749 1749 1749
# ****************************************************************************************************
# source= 1 destination= 10 Dates= 27
# BOM LKO
# 1759 1759 1759 1759 1759 1759
# ****************************************************************************************************
# source= 1 destination= 11 Dates= 27
# BOM JAI
# 1769 1769 1769 1769 1769 1769
# ****************************************************************************************************
# source= 1 destination= 12 Dates= 27
# BOM PAT
# 1779 1779 1779 1779 1779 1779
# ****************************************************************************************************
# source= 1 destination= 13 Dates= 27
# BOM TRV
# 1789 1789 1789 1789 1789 1789
# ****************************************************************************************************
# source= 1 destination= 14 Dates= 27
# BOM BBI
# 1799 1799 1799 1799 1799 1799
# ****************************************************************************************************
# source= 1 destination= 15 Dates= 27
# BOM CCJ
# 1809 1809 1809 1809 1809 1809
# ****************************************************************************************************
# source= 1 destination= 16 Dates= 27
# BOM IXB
# 1819 1819 1819 1819 1819 1819
# ****************************************************************************************************
# source= 1 destination= 17 Dates= 27
# BOM NAG
# 1829 1829 1829 1829 1829 1829
# ****************************************************************************************************
# source= 1 destination= 18 Dates= 27
# BOM VNS
# 1839 1839 1839 1839 1839 1839
# ****************************************************************************************************
# source= 1 destination= 19 Dates= 27
# BOM IDR
# 1849 1849 1849 1849 1849 1849
# ****************************************************************************************************
# source= 1 destination= 20 Dates= 27
# BOM CJB
# 1859 1859 1859 1859 1859 1859
# ****************************************************************************************************
# source= 1 destination= 21 Dates= 27
# BOM SXR
# 1869 1869 1869 1869 1869 1869
# ****************************************************************************************************
# source= 1 destination= 22 Dates= 27
# BOM VTZ
# 1879 1879 1879 1879 1879 1879
# ****************************************************************************************************
# source= 1 destination= 23 Dates= 27
# BOM IXR
# 1889 1889 1889 1889 1889 1889
# ****************************************************************************************************
# source= 1 destination= 24 Dates= 27
# BOM ATQ
# 1899 1899 1899 1899 1899 1899
# ****************************************************************************************************
# source= 1 destination= 25 Dates= 27
# BOM IXC
# 1909 1909 1909 1909 1909 1909
# ****************************************************************************************************
# source= 1 destination= 26 Dates= 27
# BOM RPR
# 1919 1919 1919 1919 1919 1919
# ****************************************************************************************************
# source= 1 destination= 27 Dates= 27
# BOM IXE
# 1929 1929 1929 1929 1929 1929
# ****************************************************************************************************
# source= 1 destination= 28 Dates= 27
# BOM IXZ
# 1939 1939 1939 1939 1939 1939
# ****************************************************************************************************
# source= 1 destination= 29 Dates= 27
# BOM TRZ
# 1949 1949 1949 1949 1949 1949
# ****************************************************************************************************
# source= 2 destination= 0 Dates= 27
# BLR DEL
# 1959 1959 1959 1959 1959 1959
# ****************************************************************************************************
# source= 2 destination= 1 Dates= 27
# BLR BOM
# 1969 1969 1969 1969 1969 1969
# ****************************************************************************************************
# source= 2 destination= 3 Dates= 27
# BLR HYD
# 1979 1979 1979 1979 1979 1979
# ****************************************************************************************************
# source= 2 destination= 4 Dates= 27
# BLR MAA
# 1989 1989 1989 1989 1989 1989
# ****************************************************************************************************
# source= 2 destination= 5 Dates= 27
# BLR CCU
# 1999 1999 1999 1999 1999 1999
# ****************************************************************************************************
# source= 2 destination= 6 Dates= 27
# BLR COK
# 2009 2009 2009 2009 2009 2009
# ****************************************************************************************************
# source= 2 destination= 7 Dates= 27
# BLR GOI
# 2019 2019 2019 2019 2019 2019
# ****************************************************************************************************
# source= 2 destination= 8 Dates= 27
# BLR PNQ
# 2029 2029 2029 2029 2029 2029
# ****************************************************************************************************
# source= 2 destination= 9 Dates= 27
# BLR GAU
# 2039 2039 2039 2039 2039 2039
# ****************************************************************************************************
# source= 2 destination= 10 Dates= 27
# BLR LKO
# 2049 2049 2049 2049 2049 2049
# ****************************************************************************************************
# source= 2 destination= 11 Dates= 27
# BLR JAI
# 2059 2059 2059 2059 2059 2059
# ****************************************************************************************************
# source= 2 destination= 12 Dates= 27
# BLR PAT
# 2069 2069 2069 2069 2069 2069
# ****************************************************************************************************
# source= 2 destination= 13 Dates= 27
# BLR TRV
# 2079 2079 2079 2079 2079 2079
# ****************************************************************************************************
# source= 2 destination= 14 Dates= 27
# BLR BBI
# 2089 2089 2089 2089 2089 2089
# ****************************************************************************************************
# source= 2 destination= 15 Dates= 27
# BLR CCJ
# 2093 2093 2093 2093 2093 2093
# ****************************************************************************************************
# source= 2 destination= 16 Dates= 27
# BLR IXB
# 2103 2103 2103 2103 2103 2103
# ****************************************************************************************************
# source= 2 destination= 17 Dates= 27
# BLR NAG
# 2113 2113 2113 2113 2113 2113
# ****************************************************************************************************
# source= 2 destination= 18 Dates= 27
# BLR VNS
# 2123 2123 2123 2123 2123 2123
# ****************************************************************************************************
# source= 2 destination= 19 Dates= 27
# BLR IDR
# 2133 2133 2133 2133 2133 2133
# ****************************************************************************************************
# source= 2 destination= 20 Dates= 27
# BLR CJB
# 2143 2143 2143 2143 2143 2143
# ****************************************************************************************************
# source= 2 destination= 21 Dates= 27
# BLR SXR
# 2153 2153 2153 2153 2153 2153
# ****************************************************************************************************
# source= 2 destination= 22 Dates= 27
# BLR VTZ
# 2163 2163 2163 2163 2163 2163
# ****************************************************************************************************
# source= 2 destination= 23 Dates= 27
# BLR IXR
# 2173 2173 2173 2173 2173 2173
# ****************************************************************************************************
# source= 2 destination= 24 Dates= 27
# BLR ATQ
# 2183 2183 2183 2183 2183 2183
# ****************************************************************************************************
# source= 2 destination= 25 Dates= 27
# BLR IXC
# 2193 2193 2193 2193 2193 2193
# ****************************************************************************************************
# source= 2 destination= 26 Dates= 27
# BLR RPR
# 2203 2203 2203 2203 2203 2203
# ****************************************************************************************************
# source= 2 destination= 27 Dates= 27
# BLR IXE
# 2213 2213 2213 2213 2213 2213
# ****************************************************************************************************
# source= 2 destination= 28 Dates= 27
# BLR IXZ
# 2223 2223 2223 2223 2223 2223
# ****************************************************************************************************
# source= 2 destination= 29 Dates= 27
# BLR TRZ
# 2232 2232 2232 2232 2232 2232
# ****************************************************************************************************
# source= 3 destination= 0 Dates= 27
# HYD DEL
# 2242 2242 2242 2242 2242 2242
# ****************************************************************************************************
# source= 3 destination= 1 Dates= 27
# HYD BOM
# 2252 2252 2252 2252 2252 2252
# ****************************************************************************************************
# source= 3 destination= 2 Dates= 27
# HYD BLR
# 2262 2262 2262 2262 2262 2262
# ****************************************************************************************************
# source= 3 destination= 4 Dates= 27
# HYD MAA
# 2272 2272 2272 2272 2272 2272
# ****************************************************************************************************
# source= 3 destination= 5 Dates= 27
# HYD CCU
# 2282 2282 2282 2282 2282 2282
# ****************************************************************************************************
# source= 3 destination= 6 Dates= 27
# HYD COK
# 2292 2292 2292 2292 2292 2292
# ****************************************************************************************************
# source= 3 destination= 7 Dates= 27
# HYD GOI
# 2302 2302 2302 2302 2302 2302
# ****************************************************************************************************
# source= 3 destination= 8 Dates= 27
# HYD PNQ
# 2312 2312 2312 2312 2312 2312
# ****************************************************************************************************
# source= 3 destination= 9 Dates= 27
# HYD GAU
# 2322 2322 2322 2322 2322 2322
# ****************************************************************************************************
# source= 3 destination= 10 Dates= 27
# HYD LKO
# 2332 2332 2332 2332 2332 2332
# ****************************************************************************************************
# source= 3 destination= 11 Dates= 27
# HYD JAI
# 2342 2342 2342 2342 2342 2342
# ****************************************************************************************************
# source= 3 destination= 12 Dates= 27
# HYD PAT
# 2352 2352 2352 2352 2352 2352
# ****************************************************************************************************
# source= 3 destination= 13 Dates= 27
# HYD TRV
# 2362 2362 2362 2362 2362 2362
# ****************************************************************************************************
# source= 3 destination= 14 Dates= 27
# HYD BBI
# 2372 2372 2372 2372 2372 2372
# ****************************************************************************************************
# source= 3 destination= 15 Dates= 27
# HYD CCJ
# 2382 2382 2382 2382 2382 2382
# ****************************************************************************************************
# source= 3 destination= 16 Dates= 27
# HYD IXB
# 2392 2392 2392 2392 2392 2392
# ****************************************************************************************************
# source= 3 destination= 17 Dates= 27
# HYD NAG
# 2402 2402 2402 2402 2402 2402
# ****************************************************************************************************
# source= 3 destination= 18 Dates= 27
# HYD VNS
# 2412 2412 2412 2412 2412 2412
# ****************************************************************************************************
# source= 3 destination= 19 Dates= 27
# HYD IDR
# 2422 2422 2422 2422 2422 2422
# ****************************************************************************************************
# source= 3 destination= 20 Dates= 27
# HYD CJB
# 2432 2432 2432 2432 2432 2432
# ****************************************************************************************************
# source= 3 destination= 21 Dates= 27
# HYD SXR
# 2442 2442 2442 2442 2442 2442
# ****************************************************************************************************
# source= 3 destination= 22 Dates= 27
# HYD VTZ
# 2452 2452 2452 2452 2452 2452
# ****************************************************************************************************
# source= 3 destination= 23 Dates= 27
# HYD IXR
# 2462 2462 2462 2462 2462 2462
# ****************************************************************************************************
# source= 3 destination= 24 Dates= 27
# HYD ATQ
# 2472 2472 2472 2472 2472 2472
# ****************************************************************************************************
# source= 3 destination= 25 Dates= 27
# HYD IXC
# 2482 2482 2482 2482 2482 2482
# ****************************************************************************************************
# source= 3 destination= 26 Dates= 27
# HYD RPR
# 2482 2482 2482 2482 2482 2482
# ****************************************************************************************************
# source= 3 destination= 27 Dates= 27
# HYD IXE
# 2492 2492 2492 2492 2492 2492
# ****************************************************************************************************
# source= 3 destination= 28 Dates= 27
# HYD IXZ
# 2492 2492 2492 2492 2492 2492
# ****************************************************************************************************
# source= 3 destination= 29 Dates= 27
# HYD TRZ
# 2502 2502 2502 2502 2502 2502
# ****************************************************************************************************
# source= 4 destination= 0 Dates= 27
# MAA DEL
# 2512 2512 2512 2512 2512 2512
# ****************************************************************************************************
# source= 4 destination= 1 Dates= 27
# MAA BOM
# 2522 2522 2522 2522 2522 2522
# ****************************************************************************************************
# source= 4 destination= 2 Dates= 27
# MAA BLR
# 2532 2532 2532 2532 2532 2532
# ****************************************************************************************************
# source= 4 destination= 3 Dates= 27
# MAA HYD
# 2542 2542 2542 2542 2542 2542
# ****************************************************************************************************
# source= 4 destination= 5 Dates= 27
# MAA CCU
# 2552 2552 2552 2552 2552 2552
# ****************************************************************************************************
# source= 4 destination= 6 Dates= 27
# MAA COK
# 2562 2562 2562 2562 2562 2562
# ****************************************************************************************************
# source= 4 destination= 7 Dates= 27
# MAA GOI
# 2572 2572 2572 2572 2572 2572
# ****************************************************************************************************
# source= 4 destination= 8 Dates= 27
# MAA PNQ
# 2582 2582 2582 2582 2582 2582
# ****************************************************************************************************
# source= 4 destination= 9 Dates= 27
# MAA GAU
# 2592 2592 2592 2592 2592 2592
# ****************************************************************************************************
# source= 4 destination= 10 Dates= 27
# MAA LKO
# 2602 2602 2602 2602 2602 2602
# ****************************************************************************************************
# source= 4 destination= 11 Dates= 27
# MAA JAI
# 2612 2612 2612 2612 2612 2612
# ****************************************************************************************************
# source= 4 destination= 12 Dates= 27
# MAA PAT
# 2622 2622 2622 2622 2622 2622
# ****************************************************************************************************
# source= 4 destination= 13 Dates= 27
# MAA TRV
# 2632 2632 2632 2632 2632 2632
# ****************************************************************************************************
# source= 4 destination= 14 Dates= 27
# MAA BBI
# 2642 2642 2642 2642 2642 2642
# ****************************************************************************************************
# source= 4 destination= 15 Dates= 27
# MAA CCJ
# 2647 2647 2647 2647 2647 2647
# ****************************************************************************************************
# source= 4 destination= 16 Dates= 27
# MAA IXB
# 2657 2657 2657 2657 2657 2657
# ****************************************************************************************************
# source= 4 destination= 17 Dates= 27
# MAA NAG
# 2667 2667 2667 2667 2667 2667
# ****************************************************************************************************
# source= 4 destination= 18 Dates= 27
# MAA VNS
# 2677 2677 2677 2677 2677 2677
# ...
# source= 1 destination= 29 Dates= 30
# BOM TRZ
# 13833 13833 13833 13833 13833 13833
# ****************************************************************************************************
# source= 2 destination= 0 Dates= 30
# BLR DEL
# 13843 13843 13843 13843 13843 13843
# ****************************************************************************************************
# source= 2 destination= 1 Dates= 30
# BLR BOM
# 13853 13853 13853 13853 13853 13853
# ****************************************************************************************************
# source= 2 destination= 3 Dates= 30
# BLR HYD
# 13863 13863 13863 13863 13863 13863
# ****************************************************************************************************
# source= 2 destination= 4 Dates= 30
# BLR MAA
# 13872 13872 13872 13872 13872 13872
# ****************************************************************************************************
# source= 2 destination= 5 Dates= 30
# BLR CCU
# 13882 13882 13882 13882 13882 13882
# ****************************************************************************************************
# source= 2 destination= 6 Dates= 30
# BLR COK
# 13892 13892 13892 13892 13892 13892
# ****************************************************************************************************
# source= 2 destination= 7 Dates= 30
# BLR GOI
# 13902 13902 13902 13902 13902 13902
# ****************************************************************************************************
# source= 2 destination= 8 Dates= 30
# BLR PNQ
# 13912 13912 13912 13912 13912 13912
# ****************************************************************************************************
# source= 2 destination= 9 Dates= 30
# BLR GAU
# 13922 13922 13922 13922 13922 13922
# ****************************************************************************************************
# source= 2 destination= 10 Dates= 30
# BLR LKO
# 13932 13932 13932 13932 13932 13932
# ****************************************************************************************************
# source= 2 destination= 11 Dates= 30
# BLR JAI
# 13936 13936 13936 13936 13936 13936
# ****************************************************************************************************
# source= 2 destination= 12 Dates= 30
# BLR PAT
# 13946 13946 13946 13946 13946 13946
# ****************************************************************************************************
# source= 2 destination= 13 Dates= 30
# BLR TRV
# 13956 13956 13956 13956 13956 13956
# ****************************************************************************************************
# source= 2 destination= 14 Dates= 30
# BLR BBI
# 13966 13966 13966 13966 13966 13966
# ****************************************************************************************************
# source= 2 destination= 15 Dates= 30
# BLR CCJ
# 13966 13966 13966 13966 13966 13966
# ****************************************************************************************************
# source= 2 destination= 16 Dates= 30
# BLR IXB
# 13976 13976 13976 13976 13976 13976
# ****************************************************************************************************
# source= 2 destination= 17 Dates= 30
# BLR NAG
# 13985 13985 13985 13985 13985 13985
# ****************************************************************************************************
# source= 2 destination= 18 Dates= 30
# BLR VNS
# 13995 13995 13995 13995 13995 13995
# ****************************************************************************************************
# source= 2 destination= 19 Dates= 30
# BLR IDR
# 14005 14005 14005 14005 14005 14005
# ****************************************************************************************************
# source= 2 destination= 20 Dates= 30
# BLR CJB
# 14007 14007 14007 14007 14007 14007
# ****************************************************************************************************
# source= 2 destination= 21 Dates= 30
# BLR SXR
# 14017 14017 14017 14017 14017 14017
# ****************************************************************************************************
# source= 2 destination= 22 Dates= 30
# BLR VTZ
# 14023 14023 14023 14023 14023 14023
# ****************************************************************************************************
# source= 2 destination= 23 Dates= 30
# BLR IXR
# 14033 14033 14033 14033 14033 14033
# ****************************************************************************************************
# source= 2 destination= 24 Dates= 30
# BLR ATQ
# 14042 14042 14042 14042 14042 14042
# ****************************************************************************************************
# source= 2 destination= 25 Dates= 30
# BLR IXC
# 14052 14052 14052 14052 14052 14052
# ****************************************************************************************************
# source= 2 destination= 26 Dates= 30
# BLR RPR
# 14062 14062 14062 14062 14062 14062
# ****************************************************************************************************
# source= 2 destination= 27 Dates= 30
# BLR IXE
# 14063 14063 14063 14063 14063 14063
# ****************************************************************************************************
# source= 2 destination= 28 Dates= 30
# BLR IXZ
# 14073 14073 14073 14073 14073 14073
# ****************************************************************************************************
# source= 2 destination= 29 Dates= 30
# BLR TRZ
# 14073 14073 14073 14073 14073 14073
# ****************************************************************************************************
# source= 3 destination= 0 Dates= 30
# HYD DEL
# 14083 14083 14083 14083 14083 14083
# ****************************************************************************************************
# source= 3 destination= 1 Dates= 30
# HYD BOM
# 14093 14093 14093 14093 14093 14093
# ****************************************************************************************************
# source= 3 destination= 2 Dates= 30
# HYD BLR
# 14103 14103 14103 14103 14103 14103
# ****************************************************************************************************
# source= 3 destination= 4 Dates= 30
# HYD MAA
# 14113 14113 14113 14113 14113 14113
# ****************************************************************************************************
# source= 3 destination= 5 Dates= 30
# HYD CCU
# 14123 14123 14123 14123 14123 14123
# ****************************************************************************************************
# source= 3 destination= 6 Dates= 30
# HYD COK
# 14133 14133 14133 14133 14133 14133
# ****************************************************************************************************
# source= 3 destination= 7 Dates= 30
# HYD GOI
# 14143 14143 14143 14143 14143 14143
# ****************************************************************************************************
# source= 3 destination= 8 Dates= 30
# HYD PNQ
# 14153 14153 14153 14153 14153 14153
# ****************************************************************************************************
# source= 3 destination= 9 Dates= 30
# HYD GAU
# 14163 14163 14163 14163 14163 14163
# ****************************************************************************************************
# source= 3 destination= 10 Dates= 30
# HYD LKO
# 14173 14173 14173 14173 14173 14173
# ****************************************************************************************************
# source= 3 destination= 11 Dates= 30
# HYD JAI
# 14178 14178 14178 14178 14178 14178
# ****************************************************************************************************
# source= 3 destination= 12 Dates= 30
# HYD PAT
# 14188 14188 14188 14188 14188 14188
# ****************************************************************************************************
# source= 3 destination= 13 Dates= 30
# HYD TRV
# 14198 14198 14198 14198 14198 14198
# ****************************************************************************************************
# source= 3 destination= 14 Dates= 30
# HYD BBI
# 14208 14208 14208 14208 14208 14208
# ****************************************************************************************************
# source= 3 destination= 15 Dates= 30
# HYD CCJ
# 14208 14208 14208 14208 14208 14208
# ****************************************************************************************************
# source= 3 destination= 16 Dates= 30
# HYD IXB
# 14218 14218 14218 14218 14218 14218
# ****************************************************************************************************
# source= 3 destination= 17 Dates= 30
# HYD NAG
# 14224 14224 14224 14224 14224 14224
# ****************************************************************************************************
# source= 3 destination= 18 Dates= 30
# HYD VNS
# 14234 14234 14234 14234 14234 14234
# ****************************************************************************************************
# source= 3 destination= 19 Dates= 30
# HYD IDR
# 14244 14244 14244 14244 14244 14244
# ****************************************************************************************************
# source= 3 destination= 20 Dates= 30
# HYD CJB
# 14248 14248 14248 14248 14248 14248
# ****************************************************************************************************
# source= 3 destination= 21 Dates= 30
# HYD SXR
# 14258 14258 14258 14258 14258 14258
# ****************************************************************************************************
# source= 3 destination= 22 Dates= 30
# HYD VTZ
# 14265 14265 14265 14265 14265 14265
# ****************************************************************************************************
# source= 3 destination= 23 Dates= 30
# HYD IXR
# 14275 14275 14275 14275 14275 14275
# ****************************************************************************************************
# source= 3 destination= 24 Dates= 30
# HYD ATQ
# 14285 14285 14285 14285 14285 14285
# ****************************************************************************************************
# source= 3 destination= 25 Dates= 30
# HYD IXC
# 14295 14295 14295 14295 14295 14295
# ****************************************************************************************************
# source= 3 destination= 26 Dates= 30
# HYD RPR
# 14305 14305 14305 14305 14305 14305
# ****************************************************************************************************
# source= 3 destination= 27 Dates= 30
# HYD IXE
# 14308 14308 14308 14308 14308 14308
# ****************************************************************************************************
# source= 3 destination= 28 Dates= 30
# HYD IXZ
# 14317 14317 14317 14317 14317 14317
# ****************************************************************************************************
# source= 3 destination= 29 Dates= 30
# HYD TRZ
# 14317 14317 14317 14317 14317 14317
# ****************************************************************************************************
# source= 4 destination= 0 Dates= 30
# MAA DEL
# 14317 14317 14317 14317 14317 14317
# ****************************************************************************************************
# source= 4 destination= 1 Dates= 30
# MAA BOM
# 14327 14327 14327 14327 14327 14327
# ****************************************************************************************************
# source= 4 destination= 2 Dates= 30
# MAA BLR
# 14337 14337 14337 14337 14337 14337
# ****************************************************************************************************
# source= 4 destination= 3 Dates= 30
# MAA HYD
# 14347 14347 14347 14347 14347 14347
# ****************************************************************************************************
# source= 4 destination= 5 Dates= 30
# MAA CCU
# 14357 14357 14357 14357 14357 14357
# ****************************************************************************************************
# source= 4 destination= 6 Dates= 30
# MAA COK
# 14367 14367 14367 14367 14367 14367
# ****************************************************************************************************
# source= 4 destination= 7 Dates= 30
# MAA GOI
# 14377 14377 14377 14377 14377 14377
# ****************************************************************************************************
# source= 4 destination= 8 Dates= 30
# MAA PNQ
# 14387 14387 14387 14387 14387 14387
# ****************************************************************************************************
# source= 4 destination= 9 Dates= 30
# MAA GAU
# 14397 14397 14397 14397 14397 14397
# ****************************************************************************************************
# source= 4 destination= 10 Dates= 30
# MAA LKO
# 14407 14407 14407 14407 14407 14407
# ****************************************************************************************************
# source= 4 destination= 11 Dates= 30
# MAA JAI
# 14409 14409 14409 14409 14409 14409
# ****************************************************************************************************
# source= 4 destination= 12 Dates= 30
# MAA PAT
# 14419 14419 14419 14419 14419 14419
# ****************************************************************************************************
# source= 4 destination= 13 Dates= 30
# MAA TRV
# 14429 14429 14429 14429 14429 14429
# ****************************************************************************************************
# source= 4 destination= 14 Dates= 30
# MAA BBI
# 14439 14439 14439 14439 14439 14439
# ****************************************************************************************************
# source= 4 destination= 15 Dates= 30
# MAA CCJ
# 14439 14439 14439 14439 14439 14439
# ****************************************************************************************************
# source= 4 destination= 16 Dates= 30
# MAA IXB
# 14449 14449 14449 14449 14449 14449
# ****************************************************************************************************
# source= 4 destination= 17 Dates= 30
# MAA NAG
# 14455 14455 14455 14455 14455 14455
# ****************************************************************************************************
# source= 4 destination= 18 Dates= 30
# MAA VNS
# 14465 14465 14465 14465 14465 14465
# ****************************************************************************************************
# source= 4 destination= 19 Dates= 30
# MAA IDR
# 14475 14475 14475 14475 14475 14475
# ****************************************************************************************************
# source= 4 destination= 20 Dates= 30
# MAA CJB
# 14480 14480 14480 14480 14480 14480
# ****************************************************************************************************
# source= 4 destination= 21 Dates= 30
# MAA SXR
# 14490 14490 14490 14490 14490 14490
# ****************************************************************************************************
# source= 4 destination= 22 Dates= 30
# MAA VTZ
# 14496 14496 14496 14496 14496 14496
# ****************************************************************************************************
# source= 4 destination= 23 Dates= 30
# MAA IXR
# 14506 14506 14506 14506 14506 14506
# ****************************************************************************************************
# source= 4 destination= 24 Dates= 30
# MAA ATQ
# 14516 14516 14516 14516 14516 14516
# ****************************************************************************************************
# source= 4 destination= 25 Dates= 30
# MAA IXC
# 14526 14526 14526 14526 14526 14526
# ****************************************************************************************************
# source= 4 destination= 26 Dates= 30
# MAA RPR
# 14536 14536 14536 14536 14536 14536
# ****************************************************************************************************
# source= 4 destination= 27 Dates= 30
# MAA IXE
# 14539 14539 14539 14539 14539 14539
# ****************************************************************************************************
# source= 4 destination= 28 Dates= 30
# MAA IXZ
# 14549 14549 14549 14549 14549 14549
# ****************************************************************************************************
# source= 4 destination= 29 Dates= 30
# MAA TRZ
# 14549 14549 14549 14549 14549 14549
# ****************************************************************************************************

# %%
data = pd.DataFrame(
    {'Price':price,
     'Cities':cities,
     'departure_time':departure_time,
     'arrival_time':arrival_time, 
     'layeover':via,
     'Airline':airline,
     'Cabin':cabin
    })

# %%
data
# Out:
#          Price                          Cities departure_time arrival_time  \
# 0        3,335    New Delhi to Mumbai , 26 May          14:30        20:20
# 1        3,335    New Delhi to Mumbai , 26 May          09:15        16:15
# 2        3,335    New Delhi to Mumbai , 26 May          20:50        04:20
# 3        3,335    New Delhi to Mumbai , 26 May          08:00        16:15
# 4        3,335    New Delhi to Mumbai , 26 May          09:25        20:20
# ...        ...                             ...            ...          ...
# 14544   79,435  Chennai to Port Blair , 30 May          14:55        09:00
# 14545   79,435  Chennai to Port Blair , 30 May          14:55        09:00
# 14546   79,625  Chennai to Port Blair , 30 May          21:05        11:20
# 14547   85,595  Chennai to Port Blair , 30 May          12:30        11:20
# 14548   85,595  Chennai to Port Blair , 30 May          12:30        11:20
#
#                                   layeover    Airline Cabin
# 0                        1 stop via Ranchi    AirAsia     E
# 1                     1 stop via Bengaluru    AirAsia     E
# 2                     1 stop via Bengaluru    AirAsia     E
# 3                     1 stop via Bengaluru    AirAsia     E
# 4                        1 stop via Ranchi    AirAsia     E
# ...                                    ...        ...   ...
# 14544          2 stop via Mumbai,New Delhi  Air India     B
# 14545          2 stop via Mumbai,New Delhi  Air India     B
# 14546         2 stop via New Delhi,Kolkata    Vistara     B
# 14547  3 stop via Mumbai,New Delhi,Kolkata    Vistara     B
# 14548  3 stop via Mumbai,New Delhi,Kolkata    Vistara     B
#
# [14549 rows x 7 columns]

# %%
print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline))

# %%
data.to_csv("0-5_maydata_part3.csv")

# %%
data_1=pd.read_csv("0-5.csv")
data_2=pd.read_csv("0-5_data.csv")

# %%
data_1.shape

# %%
data_2.shape

# %%
data_1=data_1.append(data_2)

# %%
data_1=data_1.drop_duplicates(keep="first")

# %%
data_1.shape
# Out:
# (36451, 7)

# %%
data_1.to_csv("0-5final.csv")

# %%
print(len(price),len(cities),len(departure_time),len(arrival_time),len(via),len(airline))

# %%
cities

# %%
soup.find_all('p')

# %%
for i in codes["Code"]:
    for j in codes["Code"]:
        print(i,j)

# %%
url="https://www.makemytrip.com/flight/search?itinerary=DEL-BOM-15/04/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver = webdriver.Chrome("C:/chromedriver.exe")
driver.get(url)
soup=BeautifulSoup(driver.page_source, 'lxml')

# %%
soup.find_all('ul')#,attrs={"class":"guestCounter"})
# Out:
# [<ul class="makeFlex font12"><li class="menu_Flights" data-cy="menu_Flights"><a class="active makeFlex hrtlCenter column" href="https://www.makemytrip.com/flights/"><span class="chNavIcon appendBottom2 chSprite chFlights active"></span><span class="chNavText darkGreyText"> Flights </span></a></li><li class="menu_Hotels" data-cy="menu_Hotels"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/hotels/"><span class="chNavIcon appendBottom2 chSprite chHotels"></span><span class="chNavText darkGreyText"> Hotels </span></a></li><li class="menu_Villasmore" data-cy="menu_Villasmore"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/homestays/"><span class="chNavIcon appendBottom2 chSprite chHomestays"></span><span class="chNavText darkGreyText"> Villas &amp; Apts </span></a></li><li class="menu_Holidays" data-cy="menu_Holidays"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/holidays-india/"><span class="chNavIcon appendBottom2 chSprite chHolidays"></span><span class="chNavText darkGreyText"> Holidays </span></a><span class="cruiseTag font12">+Cruise</span></li><li class="menu_Trains" data-cy="menu_Trains"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/railways/"><span class="chNavIcon appendBottom2 chSprite chTrains"></span><span class="chNavText darkGreyText"> Trains </span></a></li><li class="menu_Buses" data-cy="menu_Buses"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/bus-tickets/"><span class="chNavIcon appendBottom2 chSprite chBuses"></span><span class="chNavText darkGreyText"> Buses </span></a></li><li class="menu_Visa" data-cy="menu_Visa"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/visa/"><span class="chNavIcon appendBottom2 chSprite chVisa"></span><span class="chNavText darkGreyText"> Visa </span></a></li><li class="menu_Cabs" data-cy="menu_Cabs"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/cabs/"><span class="chNavIcon appendBottom2 chSprite chCabs"></span><span class="chNavText darkGreyText"> Cabs </span></a></li><li class="menu_Charters" data-cy="menu_Charters"><a class="makeFlex hrtlCenter column" href="https://www.makemytrip.com/charter-flights/"><span class="chNavIcon appendBottom2 chSprite chCharterFlights"></span><span class="chNavText darkGreyText"> Charter Flights </span></a><span class="font10 latoBold whiteText newTag">NEW</span></li><li class="moreItem menu_More" data-cy="menu_More"><a class="makeFlex hrtlCenter column"><span class="chNavIcon appendBottom2 chSprite chMore"></span><span class="chNavText"><span class="darkGreyText"> More </span><span class="arrow arrowDown"></span></span></a><div class="moreOption font16 latoBold"><a class="appendBottom5 blackText" data-cy="submenu_ActivitiesTours" href="https://www.makemytrip.com/activities/"> Activities &amp; Tours</a><a class="appendBottom5 blackText" data-cy="submenu_TripIdeas" href="https://www.makemytrip.com/tripideas" target="_blank"> Trip Ideas</a><a class="appendBottom5 blackText" data-cy="submenu_Giftcards" href="https://www.makemytrip.com?referrer=gcWrapper" target="_blank"> Giftcards</a><a class="appendBottom5 blackText" data-cy="submenu_MyBiz" href="//mybiz.makemytrip.com/"> My Biz</a><a class="appendBottom5 blackText" data-cy="submenu_InternationalFlights" href="https://www.makemytrip.com/international-flights/"> International Flights</a><a class="appendBottom5 blackText" data-cy="submenu_InternationalHotels" href="https://www.makemytrip.com/hotels-international/"> International Hotels</a><a class="appendBottom5 blackText" data-cy="submenu_Deals" href="https://www.makemytrip.com/daily-deals/" target="_blank"> Deals</a><a class="appendBottom5 blackText" data-cy="submenu_Blog" href="https://www.makemytrip.com/blog/?intid=Blog_HomePage_Tab_Stories" target="_blank"> Blog</a></div></li></ul>,
#  <ul class="makeFlex hrtlCenter font10 blackText"><li class="font12 makeRelative"><div class="makeFlex cursorPointer" id="loginTrigger"><span class="userInfoBoxLabel whiteText appendRight10 font10 latoBlack textCenter"><span class="chSprite chLoggedOutLogo chMy"></span></span><div class="makeFlex hrtlCenter"><div class="makeFlex spaceBetween column" data-cy="account"><span class="latoBold appendBottom2"> Login or </span><span class="latoBold"> Create Account </span></div></div></div></li></ul>,
#  <ul class="slider-list" style="box-sizing: border-box; cursor: pointer; display: block; height: 68px; margin: 0px; padding: 0px; position: relative; touch-action: pan-y pinch-zoom; transform: translate3d(0px, 0px, 0px); width: auto; transition: all 0s ease 0s;"><li class="slider-slide slide-visible slide-current" style="box-sizing: border-box; display: inline-block; height: 68px; left: 0px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Fri, Apr 16</p><p style="color: rgb(22, 190, 72);">₹ 3,340</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 102.75px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Sat, Apr 17</p><p style="color: rgb(22, 190, 72);">₹ 3,340</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 205.5px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Sun, Apr 18</p><p style="color: rgb(22, 190, 72);">₹ 3,236</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 308.25px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Mon, Apr 19</p><p style="color: rgb(22, 190, 72);">₹ 3,340</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 411px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Tue, Apr 20</p><p style="color: rgb(22, 190, 72);">₹ 3,172</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 513.75px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Wed, Apr 21</p><p style="color: rgb(22, 190, 72);">₹ 3,340</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 616.5px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 102.75px;" tabindex="-1"><div aria-hidden="false" class="weeklyFareItems" dir="ltr" tabindex="0"><a><p class="blackFont fontSize12 appendBottom3">Thu, Apr 22</p><p style="color: rgb(22, 190, 72);">₹ 3,340</p></a></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 68px; left: 719.25px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform:  ...
#  <ul style="position: relative; top: -10px; display: flex; margin: 0px; padding: 0px; list-style-type: none;"><li class="paging-item active"><button aria-label="slide 1 bullet" style="cursor: pointer; opacity: 1; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 9 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 17 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 25 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 33 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 41 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 49 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 57 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 65 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 73 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 81 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 89 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 97 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 105 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 113 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="butto ...
#  <ul class="slider-list" style="box-sizing: border-box; cursor: pointer; display: block; height: 91px; margin: 0px; padding: 0px; position: relative; touch-action: pan-y pinch-zoom; transform: translate3d(0px, 0px, 0px); width: auto; transition: all 0s ease 0s;"><li class="slider-slide slide-visible slide-current" style="box-sizing: border-box; display: inline-block; height: 91px; left: 0px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 285.333px;" tabindex="-1"><div class="dealsCard"><div class="offersTextTop"><div class="offeersText"></div><div></div></div><div class="offerCode"><div class="offeerCodeText"><font color="#000000"><b>FLAT600</b></font></div><div class="bankIcon"><span class="icon16 bgProperties" style='background-image: url("https://imgak.mmtcdn.com/flights/assets/media/dt/listing/left-filters/coupon.png?v=1");'></span></div></div><p class="dealsDetail"><font color="#4a4a4a">Use this coupon and get Flat 600 instant discount per passenger</font></p></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 91px; left: 285.333px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 285.333px;" tabindex="-1"><div class="dealsCard"><div class="offersTextTop"><div class="offeersText"></div><div></div></div><div class="offerCode"><div class="offeerCodeText"><font color="#000000"><b>TRAVELTODAY</b></font></div><div class="bankIcon"><span class="icon16 bgProperties" style='background-image: url("https://imgak.mmtcdn.com/flights/assets/media/dt/listing/left-filters/coupon.png?v=1");'></span></div></div><p class="dealsDetail"><font color="#4a4a4a">Apply this promo code and get up to Rs.2000 discount on AirAsia flights</font></p></div></li><li class="slider-slide slide-visible" style="box-sizing: border-box; display: inline-block; height: 91px; left: 570.667px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 285.333px;" tabindex="-1"><div class="dealsCard"><div class="offersTextTop"><div class="offeersText"></div><div></div></div><div class="offerCode"><div class="offeerCodeText"><font color="#000000"><b>BOOKTODAY</b></font></div><div class="bankIcon"><span class="icon16 bgProperties" style='background-image: url("https://imgak.mmtcdn.com/flights/assets/media/dt/listing/left-filters/coupon.png?v=1");'></span></div></div><p class="dealsDetail"><font color="#4a4a4a">Use this coupon and get Flat 10% instant discount</font></p></div></li><li class="slider-slide" style="box-sizing: border-box; display: inline-block; height: 91px; left: 856px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 285.333px;" tabindex="-1"><div class="dealsCard"><div class="offersTextTop"><div class="offeersText"></div><div></div></div><div class="offerCode"><div class="offeerCodeText"><font color="#000000"><b>FIRSTFLIGHT</b></font></div><div class="bankIcon"><span class="icon16 bgProperties" style='background-image: url("https://imgak.mmtcdn.com/flights/assets/media/dt/listing/left-filters/coupon.png?v=1");'></span></div></div><p class="dealsDetail"><font color="#4a4a4a">Use this code to get flat 10% off on your first flight booking.</font></p></div></li><li aria-hidden="true" class="slider-slide" inert="" style="box-sizing: border-box; display: inline-block; height: 91px; left: 1141.33px; list-style-type: none; margin: auto 0px; position: absolute; top: 0px; transform: scale(1); transition: transform 0.4s linear 0s; vertical-align: top; width: 285.333px;"><div class="dealsCard"><div class="offersTextTop"><div class="offeersText"></div><div></div></div><div class="offer ...
#  <ul style="position: relative; top: -10px; display: flex; margin: 0px; padding: 0px; list-style-type: none;"><li class="paging-item active"><button aria-label="slide 1 bullet" style="cursor: pointer; opacity: 1; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 2 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 3 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 4 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 5 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 6 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 7 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 8 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 9 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 10 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 11 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li><li class="paging-item"><button aria-label="slide 13 bullet" style="cursor: pointer; opacity: 0.5; background: transparent; border: none; fill: red;" type="button"><svg class="paging-dot" height="6" width="6"><circle cx="3" cy="3" r="3"></circle></svg></button></li></ul>]

# %%
price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})

# %%
price=[]
for j,i in enumerate(price_info):
    if j<10:
        a=str(i)
        price.append(a[43:len(a)-4])
len(price)
# Out:
# 10

# %%
s='<p class="blackText fontSize18 blackFont">₹'
len(s)
# Out:
# 43

# %%
flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
cities=[]
k=0
for i,j in enumerate(flights_info):
    if i<=10:
        k=str(j)
        if len(k)>45:
            cities.append(k[29:(len(k)-4)])

# %%
cities
# Out:
# ['New Delhi to Mumbai , 15 Apr',
#  'New Delhi to Mumbai , 15 Apr',
#  'New Delhi to Mumbai , 15 Apr',
#  'New Delhi to Mumbai , 15 Apr',
#  'New Delhi to Mumbai , 15 Apr',
#  'New Delhi to Mumbai , 15 Apr']

# %%
time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
departure_time=[]
arrival_time=[]

for i,j in enumerate(b):
    k=str(j)
    if (i%2==0):
        departure_time.append(k[82:87])
    else:
        arrival_time.append(k[82:87])

# %%
layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})

# %%
via=[]
for i in c:
    via1=[]
    k=str(i)
    via1.append(k[30:len(k)-4])
    via.append(via1)

# %%
len(via)

# %%
airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})
airline=[]
for i,j in enumerate(d):
    k=str(j)
    airline.append(k[45:len(k)-7])

len(airline)

# %%
s="<span class='boldFont blackText airlineName'>"
len(s)
